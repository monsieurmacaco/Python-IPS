# %%
pd.read_csv("data_questionnaires.csv",sep = ";")
# Out:
#      ID de la réponse   Date de soumission  Dernière page Langue de départ  \
# 0                   1  2021-06-10 09:06:03              5               fr
# 1                   2  2021-06-10 09:11:47              5               fr
# 2                   3  2021-06-10 09:48:33              5               fr
# 3                   4  2021-06-10 10:06:18              5               fr
# 4                   6  2021-06-10 11:41:31              5               fr
# ..                ...                  ...            ...              ...
# 492               855  2021-09-22 19:08:11              5               fr
# 493               857  2021-09-24 12:33:34              5               fr
# 494               858  2021-09-26 22:57:47              5               fr
# 495               861  2021-10-05 14:24:23              5               fr
# 496               869  2021-11-15 15:56:12              5               fr
#
#      Tête de série    Date de lancement Date de la dernière action  \
# 0       1002251929  2021-06-10 09:03:06        2021-06-10 09:06:03
# 1        991859487  2021-06-10 09:09:11        2021-06-10 09:11:47
# 2        609204736  2021-06-10 09:20:23        2021-06-10 09:48:33
# 3       1238332078  2021-06-10 09:46:58        2021-06-10 10:06:18
# 4        772609378  2021-06-10 11:28:40        2021-06-10 11:41:31
# ..             ...                  ...                        ...
# 492      848785192  2021-09-22 18:50:12        2021-09-22 19:08:11
# 493       34552319  2021-09-24 12:00:23        2021-09-24 12:33:34
# 494     1801699955  2021-09-26 22:52:54        2021-09-26 22:57:47
# 495      562522426  2021-10-05 14:17:23        2021-10-05 14:24:23
# 496     1815312472  2021-11-15 15:50:52        2021-11-15 15:56:12
#
#     Vous vous identifiez comme :  Renseignez votre âge.   \
# 0                       Une femme                     26
# 1                       Une femme                     24
# 2                       Une femme                     32
# 3                       Une femme                     46
# 4                       Une femme                     49
# ..                            ...                    ...
# 492                     Une femme                 37 ans
# 493                     Une femme                 42 ans
# 494                     Une femme                     31
# 495                      Un homme                     34
# 496                      Un homme                     46
#
#     Sélectionnez l'académie dans laquelle vous exercez.   ...  \
# 0                               Académie de Versailles    ...
# 1                               Académie de Versailles    ...
# 2                                                  NaN    ...
# 3                               Académie de Versailles    ...
# 4                                    Académie de Paris    ...
# ..                                                 ...    ...
# 492                                   Académie de Nice    ...
# 493                                   Académie de Nice    ...
# 494                             Académie de Guadeloupe    ...
# 495                               Académie de Grenoble    ...
# 496                             Académie de Nancy-Metz    ...
#
#     Parmi les thèmes de spécialité en Terminale, quels sont les thèmes les plus appréciés par vos élèves ? [Thème 1 terminale -  De nouveaux espaces de conquête]  \
# 0                                                  Non
# 1                                                  Non
# 2                                                  Non
# 3                                                  Non
# 4                                                  Non
# ..                                                 ...
# 492                                                Non
# 493                                                Non
# 494                                                Non
# 495                                                Non
# 496                                                Non
#
#     Parmi les thèmes de spécialité en Terminale, quels sont les thèmes les plus appréciés par vos élèves ? [Thème 2 terminale - Faire la guerre, faire la paix : formes de conflits et modes de résolution]  \
# 0                                                  Non
# 1                                                  Non
# 2                                                  Non
# 3                                                  Oui
# 4                                                  Non
# ..                                                 ...
# 492                                                Non
# 493                                                Non
# 494                                                Non
# 495                                                Oui
# 496                                                Non
#
#     Parmi les thèmes de spécialité en Terminale, quels sont les thèmes les plus appréciés par vos élèves ? [Thème 3 terminale -  Histoire et mémoires]  \
# 0                                                  Non
# 1                                                  Non
# 2                                                  Non
# 3                                                  Non
# 4                                                  Non
# ..                                                 ...
# 492                                                Non
# 493                                                Non
# 494                                                Non
# 495                                                Non
# 496                                                Non
#
#     Parmi les thèmes de spécialité en Terminale, quels sont les thèmes les plus appréciés par vos élèves ? [Thème 4 terminale - Identifier, protéger et valoriser le patrimoine : enjeux géopolitiques]  \
# 0                                                  Oui
# 1                                                  Non
# 2                                                  Non
# 3                                                  Oui
# 4                                                  Non
# ..                                                 ...
# 492                                                Non
# 493                                                Non
# 494                                                Non
# 495                                                Oui
# 496                                                Non
#
#     Parmi les thèmes de spécialité en Terminale, quels sont les thèmes les plus appréciés par vos élèves ? [Thème 5 terminale - L’environnement, entre exploitation et protection : un enjeu planétaire]  \
# 0                                                  Non
# 1                                                  Non
# 2                                                  Non
# 3                                                  Non
# 4                                                  Non
# ..                                                 ...
# 492                                                Non
# 493                                                Non
# 494                                                Non
# 495                                                Non
# 496                                                Non
#
#     Parmi les thèmes de spécialité en Terminale, quels sont les thèmes les plus appréciés par vos élèves ? [Thème 6 terminale - L’enjeu de la connaissance]  \
# 0                                                  Non
# 1                                                  Non
# 2                                                  Non
# 3                                                  Oui
# 4                                                  Non
# ..                                                 ...
# 492                                                Non
# 493                                                Non
# 494                                                Non
# 495                                                Non
# 496                                                Non
#
#     Parmi les thèmes de spécialité en Terminale, quels sont les thèmes les plus appréciés par vos élèves ? [Je n'enseigne pas la spécialité HGGSP en classe de terminale.]  \
# 0                                                  Non
# 1                                                  Non
# 2                                                  Oui
# 3                                                  Non
# 4                                                  Non
# ..                                                 ...
# 492                                                Oui
# 493                                                Oui
# 494                                                Non
# 495                                                Non
# 496                                                Non
#
#     Souhaitez-vous être tenu informé.e des résultats de cette enquête ?   \
# 0                                                  Oui
# 1                                                  Oui
# 2                                                  Oui
# 3                                                  Oui
# 4                                                  Oui
# ..                                                 ...
# 492                                                Oui
# 493                                                Oui
# 494                                                Non
# 495                                                Oui
# 496                                                Oui
#
#     Souhaitez-vous participer à un entretien individuel sur cette thématique ?   Vos impressions, vécus et retours sur l'enseignement de la géopolitique me sont essentiels pour avancer plus aisément dans mes recherches. N'hésitez pas à participer !  \
# 0                                                  Oui
# 1                                                  Oui
# 2                                                  Oui
# 3                                                  Oui
# 4                                                  Non
# ..                                                 ...
# 492                                                Oui
# 493                                                Oui
# 494                                                Non
# 495                                                Oui
# 496                                                Non
#
#     Pour que je puisse vous tenir informé.e des résultats de mes recherches et/ou pour que je puisse vous contatcer pour organiser un entretien, merci de renseigner votre adresse mail.
# 0                           marion.giuliani1@gmail.com
# 1                                flo.benisty@gmail.com
# 2                            charline.machin@gmail.com
# 3             Barbara.jamin-de-capua@ac-versailles.fr
# 4    patricia.lehut@ac-paris.fr (je veux bien aprti...
# ..                                                 ...
# 492                         granet.elisabeth@gmail.com
# 493                           celinebaccari@hotmail.fr
# 494                                                NaN
# 495                         pierrelahousse87@gmail.com
# 496                 frederic.claeyman@ac-nancy-metz.fr
#
# [497 rows x 111 columns]

# %%
import requests
import pandas as pd
import numpy as np
 
df = pd.read_csv("data_questionnaires.csv",sep = ";")
df = df.drop(columns = ["ID de la réponse","Date de soumission","Dernière page", "Langue de départ","Tête de série", "Date de lancement", "Date de la dernière action"])
names_columns = df.columns



#22 : nom lycée dans colonne 22



def adresse_to_coordonnees(string):
    def string_to_request(string):
        replace = string.replace(" ","+")
        return replace
    url = 'https://nominatim.openstreetmap.org/search.php?q=' + string_to_request(string) + '&format=jsonv2'
    response = requests.get(url)
    if response.json() != []:
        json = response.json()[0]
        latitude  = float(json["lat"])
        longitude = float(json["lon"])
        boolean = True
    else:
        boolean = False
        latitude = 0
        longitude = 0
    return boolean,longitude,latitude

def make_coord(df):
    colonne_lycee = df[df.columns[22]]
    liste_longitude = []
    liste_latitude = []
    liste_index = []
    for index,lycee in enumerate(colonne_lycee):
        try:
            boolean,longitude,latitude = adresse_to_coordonnees(lycee)
            if boolean:
                print(longitude,latitude)
                liste_index.append(index)
                liste_longitude.append(longitude)
                liste_latitude.append(latitude)
            else:
                liste_index.append(index)
                liste_longitude.append("a chercher")
                liste_latitude.append("a chercher")
                print("à chercher")
        except:
            print("non renseigné")
    return liste_index,liste_latitude,liste_longitude

def make_df_from_coord(df,numero_colonne_info_en_plus):
    liste_index,liste_latitude,liste_longitude = make_coord(df)
    liste_info = list(df[df.columns[numero_colonne_info_en_plus]][liste_index])
    array = np.array(liste_info,liste_longitude,liste_latitude)
    df_coord = pd.DataFrame(np.transpose(array),columns = [names_columns[numero_colonne_info_en_plus],"longitude","latitude"])
    return df_coord
            


def make_csv(df,numero_colonne_info_en_plus,nom_csv):
    df_coord = make_df_from_coord(df, numero_colonne_info_en_plus)
    df_coord.to_csv(nom_csv)

# %%
print(names_columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(names_columns)
#
# NameError: name 'names_columns' is not defined

# %%
make_csv(df, 22, "ee" )
# Out:
# 2.3260293840688933 48.9407344
# 2.3260293840688933 48.9407344
# 2.3260293840688933 48.9407344
# 2.2780165909890355 48.8970314
# non renseigné
# à chercher
# à chercher
# non renseigné
# 0.20049011759429847 48.01120365
# 0.6142176133305135 44.19796635
# 5.4145036 43.3252202
# 4.045166714161439 49.25838505
# 0.5530300027099536 48.5131121
# 2.446363738945377 48.7790186
# à chercher
# 1.4782311 43.5774012
# à chercher
# à chercher
# 4.795227554811718 43.64037855
# à chercher
# à chercher
# 2.3465007150919557 43.222105799999994
# 3.2100408320000007 43.343443050000005
# non renseigné
# 2.3465007150919557 43.222105799999994
# non renseigné
# à chercher
# 1.1393683 49.0079154
# à chercher
# non renseigné

# %%
urlips = "https://data.education.gouv.fr/explore/dataset/fr-en-ips_lycees/table/?disjunctive.rentree_scolaire&disjunctive.academie&disjunctive.code_du_departement&disjunctive.departement&disjunctive.uai&disjunctive.nom_de_l_etablissment&disjunctive.code_insee_de_la_commune&disjunctive.nom_de_la_commune&disjunctive.secteur&disjunctive.type_de_lycee&refine.rentree_scolaire=2021-2022&dataChart=..."
